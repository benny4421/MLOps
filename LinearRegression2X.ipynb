# %% [markdown]
# <a href="https://colab.research.google.com/github/benny4421/MLOps/blob/main/LinearRegression2X.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from itertools import combinations
import joblib

data = pd.read_csv("sampregdata.csv")

x_list = ["x1", "x2", "x3", "x4"]

for pair in combinations(x_list, 2):
    X = data[list(pair)]
    y = data["y"]

    model = LinearRegression()
    model.fit(X, y)

    predictions = model.predict(X)
    r2 = r2_score(y, predictions)

    print(pair, r2)

X = data[["x3", "x4"]]
y = data["y"]

model = LinearRegression()
model.fit(X, y)

print("Intercept:", model.intercept_)
print("Coefficients:", model.coef_)
print("R-squared:", model.score(X, y))
# Out:
# ('x1', 'x2') 0.3335790615993718
# ('x1', 'x3') 0.40231449727406887
# ('x1', 'x4') 0.2778308943612612
# ('x2', 'x3') 0.3735694416909344
# ('x2', 'x4') 0.5135537867830376
# ('x3', 'x4') 0.5300160790946037
# Intercept: 4.8954987132153285
# Coefficients: [ 0.5825677  -1.37960759]
# R-squared: 0.5300160790946037
